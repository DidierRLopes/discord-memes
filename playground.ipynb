# %%
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
from textwrap import wrap

plt.rcParams["font.family"] = "impact"
  
def spongebob_stupid(txt: str):
    image = plt.imread('memes/spongebob.jpg')
    fig, ax = plt.subplots()
    ax.imshow(image)
    ax.axis('off')

    fig.text(
        0.5,
        0.2,
        "\n".join(wrap(txt, 40)),
        fontsize=20,
        color="white",
        alpha=0.9,
        horizontalalignment="center",
        path_effects=[pe.withStroke(linewidth=4, foreground="black")]
    )

    plt.show()

# %%
spongebob_stupid("pLEaSe hELP mE")

# %%
import pyimgur

# %%
memes_imgur = pyimgur.Imgur("2c6ae1b42387fba")

# %%
uploaded_image = memes_imgur.upload_image(
    "memes/chloe.jpg",
)
uploaded_image.link
# Out:
# 'https://i.imgur.com/8CzDeBY.jpg'

# %%
vars(memes_imgur)
# Out:
# {'is_authenticated': False,
#  'access_token': None,
#  'client_id': '2c6ae1b42387fba',
#  'client_secret': None,
#  'DEFAULT_LIMIT': 100,
#  'ratelimit_clientlimit': None,
#  'ratelimit_clientremaining': None,
#  'ratelimit_userlimit': None,
#  'ratelimit_userremaining': None,
#  'ratelimit_userreset': None,
#  'refresh_token': None,
#  'verify': True,
#  'mashape_key': None,
#  '_base_url': 'https://api.imgur.com'}

# %%
image = plt.imread('memes/spongebob.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

fig.text(
    0.5,
    0.2,
    "\n".join(wrap(txt, 40)),
    fontsize=20,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
nm = "asd"
txt = "ADAD ASDASDAS DSADasdasdasda asdasdasda sda sda"

image = plt.imread('memes/dogecheems.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

fig.text(
    0.25,
    0.8,
    "\n".join(wrap(nm, 20)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="left",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

fig.text(
    0.25,
    0.2,
    "\n".join(wrap(txt, 20)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="left",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

fig.text(
    0.65,
    0.2,
    "\n".join(wrap(txt, 20)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="left",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

fig.text(
    0.75,
    0.8,
    "\n".join(wrap(nm, 20)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="left",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)


plt.show()

# %%
image = plt.imread('memes/stonks.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

txt = "stonks"

fig.text(
    0.675,
    0.39,
    "\n".join(wrap(txt, 15)),
    fontsize=20,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/bernie.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

txt = "for your love"

fig.text(
    0.5,
    0.2,
    "\n".join(wrap(txt, 20)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/butterfly.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

person = "didier"
butterfly = "meme"
question = "is this a meme?"

fig.text(
    0.38,
    0.8,
    "\n".join(wrap(person.upper(), 20)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.7,
    0.55,
    "\n".join(wrap(butterfly.upper(), 20)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.5,
    0.2,
    "\n".join(wrap(question.upper(), 20)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/anakin.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

anakin = "didie asdasd asd asd r"
padme = "mem asdasd asd asdasd asde"
padmesurprised = "is this a meme  asdasd asd a ?"

fig.text(
    0.38,
    0.55,
    "\n".join(wrap(anakin.upper(), 18)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.64,
    0.53,
    "\n".join(wrap(padme.upper(), 18)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.64,
    0.16,
    "\n".join(wrap(padmesurprised.upper(), 25)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/bikefall.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

riding = "didie asdasd asd asd rdidie asdasd asd asd"
putstick = "mem asdasd asd asdasd asddidie asdasd asd asde"
fall = "is this a ie asdasd asd asd ?"

fig.text(
    0.6,
    0.75,
    "\n".join(wrap(riding.upper(), 18)),
    fontsize=6,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.42,
    0.47,
    "\n".join(wrap(putstick.upper(), 15)),
    fontsize=6,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.6,
    0.32,
    "\n".join(wrap(fall.upper(), 25)),
    fontsize=6,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/buzz.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

top = "didier"
bottom = "meme"

fig.text(
    0.5,
    0.8,
    "\n".join(wrap(top.upper(), 20)),
    fontsize=18,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.5,
    0.2,
    "\n".join(wrap(bottom.upper(), 20)),
    fontsize=18,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/cardboard.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text = "didier asdasder asdasd asd asd asdasd asd asd as asd asd asdasd asd asd asd"

fig.text(
    0.54,
    0.67,
    "\n".join(wrap(text.upper(), 17)),
    fontsize=8,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/clown.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text1 = "didier asdasder asdasd asd asd asdas"
text2 = "didier asdasder asdasd asd asd asdas"
text3 = "didier asdasder asdasd asd asd asdas"
text4 = "didier asdasder asdasd asd asd asdas"

fig.text(
    0.4,
    0.8,
    "\n".join(wrap(text1.upper(), 25)),
    fontsize=8,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.4,
    0.6,
    "\n".join(wrap(text2.upper(), 25)),
    fontsize=8,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.4,
    0.4,
    "\n".join(wrap(text2.upper(), 25)),
    fontsize=8,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.4,
    0.2,
    "\n".join(wrap(text2.upper(), 25)),
    fontsize=8,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/conspiracy.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

person = "didier asdasder asdasd asd asd asdas"
text = "didier asdasder asdasd asd asd asder asdasder asdasd asd asd asder asdasder asdasd asd asd asder asdasder asdasd asd asd asdas"

fig.text(
    0.5,
    0.8,
    "\n".join(wrap(person.upper(), 60)),
    fontsize=8,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.5,
    0.2,
    "\n".join(wrap(text.upper(), 60)),
    fontsize=8,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/cryingkid.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

kid = "didier asdasder asdasd asd asd asdas"
adult = "didier asdasder ad asd asdas"
text = "didier asdasde asdasd asd asder asdasd asd asd asdas"


fig.text(
    0.5,
    0.65,
    "\n".join(wrap(kid.upper(), 35)),
    fontsize=8,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.5,
    0.4,
    "\n".join(wrap(adult.upper(), 35)),
    fontsize=8,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.5,
    0.18,
    "\n".join(wrap(text.upper(), 35)),
    fontsize=8,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/dicaprio.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text = "didier asdasde asdasd asd asder asdasd asd asd asdas"

fig.text(
    0.5,
    0.2,
    "\n".join(wrap(text.upper(), 35)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/disappointed.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text1 = "didier asdasde asdasd asd asder asdasd asd asd asdas"
text2 = "didier asdasde asdasd asd asder asdasd asd asd asdas"

fig.text(
    0.35,
    0.7,
    "\n".join(wrap(text1.upper(), 35)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

fig.text(
    0.35,
    0.3,
    "\n".join(wrap(text2.upper(), 35)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/dosomething.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text1 = "didier asdasde asdasd asd asder asdasd asd asd asdas"
text2 = "didier asdasde asddier asdasde asdasd asd asder asd asd asder asdasd asd asd asdas"

fig.text(
    0.55,
    0.7,
    "C'mon, do something",
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

fig.text(
    0.55,
    0.25,
    "\n".join(wrap(text2.upper(), 30)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/drake.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text1 = "didier asdasde asdasd asd asder asdasd asd asd asdas"
text2 = "didier asdasde asddier asdasde asdasd asd asder asd asd asder asdasd asd asd asdas"

fig.text(
    0.7,
    0.7,
    "\n".join(wrap(text1.upper(), 30)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

fig.text(
    0.7,
    0.3,
    "\n".join(wrap(text2.upper(), 30)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/firedog.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text1 = "didier asdasde asdasd asd asder asdasd asd asd asdas"
text2 = "didier asdasde asddier asdasde asdasd asd asder asd asd asder asdasd asd asd asdas"

fig.text(
    0.33,
    0.7,
    "\n".join(wrap(text1.upper(), 35)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/firegirl.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text1 = "didier asdasde asdasd asd asder asdasd asd asd asdas"
text2 = "didier asdasde asddier asdasde asdasd asd asder asd asd asder asdasd asd asd asdas"

fig.text(
    0.5,
    0.8,
    "\n".join(wrap(text1.upper(), 50)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

fig.text(
    0.5,
    0.2,
    "\n".join(wrap(text2.upper(), 50)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/flextape.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

person = "didier"
problem = "diidier asdasde asidier asdasde asdier asdasde ass"
solution = "diidier asdasde asidier"

fig.text(
    0.42,
    0.6,
    "\n".join(wrap(person.upper(), 30)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.6,
    0.8,
    "\n".join(wrap(problem.upper(), 25)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

fig.text(
    0.51,
    0.2,
    "\n".join(wrap(text2.upper(), 40)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/fry.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text1 = "diidier asdasde asidier asdasde asdier asdasde ass"
text2 = "diidier dier asdasde asidier asdasde asdasde asidier"


fig.text(
    0.51,
    0.8,
    "\n".join(wrap(text1.upper(), 55)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

fig.text(
    0.51,
    0.2,
    "\n".join(wrap(text2.upper(), 55)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/gettingpaid.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text = "diidier asdasde asidier asdasde asdier asdasde ass"

fig.text(
    0.51,
    0.2,
    "\n".join(wrap(text.upper(), 55)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/goosebumps.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text = "diidier asdasde asidier asdasde asdier asdasde ass"

fig.text(
    0.52,
    0.8,
    "\n".join(wrap(text.upper(), 40)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/grandma.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text1 = "diidier asdasde asidier asdasde asdier asdasde ass"
text2 = "diidier asdasde asidier asdasde asdier asdasde ass"

fig.text(
    0.52,
    0.83,
    "\n".join(wrap(text1.upper(), 50)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.52,
    0.2,
    "\n".join(wrap(text2.upper(), 50)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/grave.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text1 = "diidier asdass"
text2 = "diidier asdasde asidier asdasde asdier asdasde ass"

fig.text(
    0.39,
    0.6,
    "\n".join(wrap(text1.upper(), 30)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.6,
    0.3,
    "\n".join(wrap(text2.upper(), 30)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/handshake.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

left = "diidier asdass"
right = "diidier asdasdes"
handshake = "diidier asdasde asidier asdasde asdier asdasde ass"

fig.text(
    0.3,
    0.4,
    "\n".join(wrap(left.upper(), 30)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.7,
    0.4,
    "\n".join(wrap(right.upper(), 30)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.5,
    0.7,
    "\n".join(wrap(handshake.upper(), 30)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/harold.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text1 = "diidier asidier asdasde asi asdasde asi asdasde asidier dass"
text2 = "diidier asdidier asdasd asdasde asi asdasde asie asidier asdes"

fig.text(
    0.51,
    0.55,
    "\n".join(wrap(text1.upper(), 40)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

fig.text(
    0.51,
    0.18,
    "\n".join(wrap(text2.upper(), 40)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)


plt.show()

# %%
image = plt.imread('memes/headout.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text1 = "diidier ae asidier dass"
text2 = "diidier asdid asdes"

fig.text(
    0.3,
    0.8,
    "\n".join(wrap(text1.upper(), 35)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="left",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.3,
    0.76,
    "\n".join(wrap(text2.upper(), 35)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="left",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)



plt.show()

# %%
image = plt.imread('memes/math.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text = "diidier aedier ae asidier d asier ae asidier d asidier dass"

fig.text(
    0.3,
    0.55,
    "\n".join(wrap(text.upper(), 35)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/pooh.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text = "diidier aedier ae asidier d asier ae asidier d asidier dass"

fig.text(
    0.65,
    0.7,
    "\n".join(wrap(text.upper(), 32)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.65,
    0.3,
    "\n".join(wrap(text.upper(), 32)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/samepic.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text1 = "diidier aedier ae aier d asidier dass"
text2 = "diidsidier d asidier dass"

fig.text(
    0.65,
    0.7,
    "\n".join(wrap(text1.upper(), 20)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.4,
    0.75,
    "\n".join(wrap(text2.upper(), 20)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/scientist.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text = "diidier aedier ae ai ae aier d sidie ae aier d sidieer d sidier d asidier daasidier dass"

fig.text(
    0.5,
    0.26,
    "\n".join(wrap(text.upper(), 70)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/skeptical.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text = "diidier aedier ae aier d sidier d asidier daasidier dass"

fig.text(
    0.5,
    0.8,
    "\n".join(wrap(text.upper(), 40)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)
fig.text(
    0.5,
    0.2,
    "\n".join(wrap(text.upper(), 40)),
    fontsize=10,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/think.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text = "diidier aedier adier aedier ae aier d sidier d e aier d sidier d asidier daasidier dass"

fig.text(
    0.5,
    0.26,
    "\n".join(wrap(text.upper(), 70)),
    fontsize=12,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()

# %%
image = plt.imread('memes/uno.jpg')
fig, ax = plt.subplots()
ax.imshow(image)
ax.axis('off')

text = "diidier aedier adier ier d asidier daasidier dass"

fig.text(
    0.42,
    0.6,
    "\n".join(wrap(text.upper(), 20)),
    fontsize=9,
    color="white",
    alpha=0.9,
    horizontalalignment="center",
    verticalalignment="center",
    path_effects=[pe.withStroke(linewidth=4, foreground="black")]
)

plt.show()
